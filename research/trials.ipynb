# %%
d={"key": "value", "key2": "value2"}

# %%
d['key']
# Out:
# 'value'

# %%
d.key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 d.key
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
from box import ConfigBox

# %%
d1={"key": "value", "key2": "value2"}
d2= ConfigBox(d1)

# %%
d2.key
# Out:
# 'value'

# %%
type(d2)
# Out:
# box.config_box.ConfigBox

# %%
#ensure annotations
from ensure import ensure_annotations

# %%
@ensure_annotations
def prod(x: int, y: int) -> int:
    return x * y

# %%
prod(2, 3)
# Out:
# 6

# %%
prod(2,'3')
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 prod(2,'3')
#
# File c:\Users\ASUS\anaconda3\envs\kidney\Lib\site-packages\ensure\main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function prod at 0x0000025CC28EFB60> does not match annotation type <class 'int'>

# %% [markdown]
# #Download  Data from Gdrive

# %%
import gdown

# %%
url="https://drive.google.com/file/d/1xl2zHr4TNCJvkrxbIbQWB5YLHf3h0pMb/view?usp=sharing"

# %%
url.split("/")
# Out:
# ['https:',
#  '',
#  'drive.google.com',
#  'file',
#  'd',
#  '1xl2zHr4TNCJvkrxbIbQWB5YLHf3h0pMb',
#  'view?usp=sharing']

# %%
folder_id = url.split("/")[-2]

# %%
print (folder_id)
# Out:
# 1xl2zHr4TNCJvkrxbIbQWB5YLHf3h0pMb

# %%
prefix = "https://drive.google.com/uc?export=download&id="

url = prefix + folder_id

gdown.download(url, "CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone.zip", quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1xl2zHr4TNCJvkrxbIbQWB5YLHf3h0pMb
# From (redirected): https://drive.google.com/uc?id=1xl2zHr4TNCJvkrxbIbQWB5YLHf3h0pMb&confirm=t&uuid=64159433-deb2-4a8a-b2d4-76fa2f56d749
# To: e:\T-Classify\research\CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone.zip
# 100%|██████████| 1.63G/1.63G [03:17<00:00, 8.23MB/s]
# 'CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone.zip'
